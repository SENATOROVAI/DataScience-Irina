# %%
"""Module providing a basic python."""
# Out:
# 'Module providing a basic python.'

# %%
from typing import Any, List

# %%
number = 1

# %% [markdown]
# 1. black(shift+alt+f) this is a plagin autoformatting code
# 2. official documentational style nympy or google

# %%
first: str = "gdg"

# %%
list_number: List[Any] = []

# %% [markdown]
# 1. If when we push pull show button stash it means conflict of files. it has changes on local machine and in github at the same fale.
# 2. to avoid conflicts need use button stash (clipboard) than git pull and restore stash.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# 1. push hw
# 2. write summary
# 3. commit to main
# 4. git push
# 5. log.ipy
